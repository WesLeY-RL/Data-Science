# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/PARARAIO - PARARAIO (1).csv",decimal = ",")

# %%
data.head(10)
# Out:
#          DATE      TIME  aleta_ceramica  inf_pastilha  inf_resist  \
# 0  24/03/2022  14:43:42            23.8          23.5        23.2
# 1  24/03/2022  14:44:13            23.8          23.5        23.2
# 2  24/03/2022  14:44:33            23.8          23.5        23.2
# 3  24/03/2022  14:44:53            23.8          23.5        23.2
# 4  24/03/2022  14:45:13            23.8          23.5        23.2
# 5  24/03/2022  14:45:33            23.8          23.5        23.2
# 6  24/03/2022  14:45:53            23.8          23.5        23.2
# 7  01/04/2022  12:49:27            20.7          21.4        21.6
# 8  01/04/2022  12:49:47            21.6          22.5        24.4
# 9  01/04/2022  12:50:07            21.7          22.8        25.2
#
#    intermed_past  intermed_resist  parede_ceramica  sup_pastilha  sup_resist
# 0           22.6             22.4             23.3          22.8        22.5
# 1           22.6             22.4             23.3          22.8        22.5
# ...

# %%
data["DATE"].unique()
# Out:
# array(['24/03/2022', '01/04/2022', '06/04/2022', '13/04/2022'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             1775 non-null   object
#  1   TIME             1775 non-null   object
#  2   aleta_ceramica   1775 non-null   float64
#  3   inf_pastilha     1775 non-null   float64
#  4   inf_resist       1775 non-null   float64
#  5   intermed_past    1775 non-null   float64
#  6   intermed_resist  1775 non-null   float64
#  7   parede_ceramica  1775 non-null   float64
#  8   sup_pastilha     1775 non-null   float64
#  9   sup_resist       1775 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 138.8+ KB

# %%
dia = data["DATE"] == "24/03/2022"
data[dia]
# Out:
#          DATE      TIME  aleta_ceramica  inf_pastilha  inf_resist  \
# 0  24/03/2022  14:43:42            23.8          23.5        23.2
# 1  24/03/2022  14:44:13            23.8          23.5        23.2
# 2  24/03/2022  14:44:33            23.8          23.5        23.2
# 3  24/03/2022  14:44:53            23.8          23.5        23.2
# 4  24/03/2022  14:45:13            23.8          23.5        23.2
# 5  24/03/2022  14:45:33            23.8          23.5        23.2
# 6  24/03/2022  14:45:53            23.8          23.5        23.2
#
#    intermed_past  intermed_resist  parede_ceramica  sup_pastilha  sup_resist
# 0           22.6             22.4             23.3          22.8        22.5
# 1           22.6             22.4             23.3          22.8        22.5
# 2           22.6             22.4             23.2          22.8        22.5
# 3           22.6             22.4             23.2          22.8        22.5
# ...

# %%
dia_01  = data["DATE"] == "01/04/2022"
data[dia_01]
# Out:
#             DATE      TIME  aleta_ceramica  inf_pastilha  inf_resist  \
# 7     01/04/2022  12:49:27            20.7          21.4        21.6
# 8     01/04/2022  12:49:47            21.6          22.5        24.4
# 9     01/04/2022  12:50:07            21.7          22.8        25.2
# 10    01/04/2022  12:50:27            21.7          23.2        25.9
# 11    01/04/2022  12:50:47            21.8          23.6        26.5
# ...          ...       ...             ...           ...         ...
# 1283  01/04/2022  19:54:47            34.8          71.8        74.9
# 1284  01/04/2022  19:55:07            34.8          71.8        74.9
# 1285  01/04/2022  19:55:27            34.9          71.9        74.9
# 1286  01/04/2022  19:55:47            34.8          71.9        74.9
# 1287  01/04/2022  19:56:07            34.9          71.9        74.9
#
#       intermed_past  intermed_resist  parede_ceramica  sup_pastilha  \
# 7              21.2             22.0             20.2          21.5
# ...

# %%
dia = data["DATE"] == "13/04/2022"
data[dia]
# Out:
#             DATE      TIME  aleta_ceramica  inf_pastilha  inf_resist  \
# 1318  13/04/2022  11:52:41            21.4          21.5        21.5
# 1319  13/04/2022  11:53:01            22.4          22.5        24.1
# 1320  13/04/2022  11:53:21            22.5          22.8        25.1
# 1321  13/04/2022  11:53:41            22.4          23.1        25.7
# 1322  13/04/2022  11:54:01            22.5          23.6        26.4
# ...          ...       ...             ...           ...         ...
# 1770  13/04/2022  14:46:07            24.4          53.5        51.6
# 1771  13/04/2022  14:46:27            24.3          53.2        51.3
# 1772  13/04/2022  14:46:47            24.2          53.0        51.0
# 1773  13/04/2022  14:47:07            24.3          52.8        50.8
# 1774  13/04/2022  14:47:27            24.4          52.6        50.6
#
#       intermed_past  intermed_resist  parede_ceramica  sup_pastilha  \
# 1318           21.5             21.5             21.0          21.9
# ...

# %%
axis=data[['DATE','TIME','aleta_ceramica','inf_pastilha','inf_resist','intermed_past','intermed_resist','parede_ceramica','sup_pastilha','sup_resist']].plot.line(subplots=True, layout=(15,2), figsize=(20,10))

# %%
minimo = data.min()
maximo = data.max()


print(minimo,maximo)
# Out:
# DATE               01/04/2022
# TIME                 07:59:49
# aleta_ceramica           20.7
# inf_pastilha             21.4
# inf_resist               21.5
# intermed_past            21.2
# intermed_resist          21.5
# parede_ceramica         -70.5
# sup_pastilha             21.5
# sup_resist               21.3
# dtype: object DATE               24/03/2022
# TIME                 19:56:07
# aleta_ceramica           34.9
# inf_pastilha             72.0
# inf_resist               75.0
# intermed_past            67.5
# intermed_resist          73.1
# parede_ceramica          28.3
# sup_pastilha             56.9
# sup_resist               63.4
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             1775 non-null   object
#  1   TIME             1775 non-null   object
#  2   aleta_ceramica   1775 non-null   float64
#  3   inf_pastilha     1775 non-null   float64
#  4   inf_resist       1775 non-null   float64
#  5   intermed_past    1775 non-null   float64
#  6   intermed_resist  1775 non-null   float64
#  7   parede_ceramica  1775 non-null   float64
#  8   sup_pastilha     1775 non-null   float64
#  9   sup_resist       1775 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 138.8+ KB

# %%
data.describe()
# Out:
#        aleta_ceramica  inf_pastilha   inf_resist  intermed_past  \
# count     1775.000000   1775.000000  1775.000000    1775.000000
# mean        27.291831     59.037239    62.667324      53.579324
# std          3.795465     11.614141    11.492609      10.945590
# min         20.700000     21.400000    21.500000      21.200000
# 25%         24.600000     54.100000    58.100000      47.800000
# 50%         25.400000     62.400000    65.900000      55.900000
# 75%         30.800000     67.400000    70.700000      62.000000
# max         34.900000     72.000000    75.000000      67.500000
#
#        intermed_resist  parede_ceramica  sup_pastilha   sup_resist
# count      1775.000000      1775.000000   1775.000000  1775.000000
# mean         58.726592        24.475944     44.976676    51.621690
# std          11.693717         3.002065      8.519310     8.824819
# min          21.500000       -70.500000     21.500000    21.300000
# ...

# %%
colunas = data.columns.values
print(colunas)
# Out:
# ['DATE' 'TIME' 'aleta_ceramica' 'inf_pastilha' 'inf_resist'
#  'intermed_past' 'intermed_resist' 'parede_ceramica' 'sup_pastilha'
#  'sup_resist']

# %%
data[dia_01]
# Out:
#             DATE      TIME  aleta_ceramica  inf_pastilha  inf_resist  \
# 7     01/04/2022  12:49:27            20.7          21.4        21.6
# 8     01/04/2022  12:49:47            21.6          22.5        24.4
# 9     01/04/2022  12:50:07            21.7          22.8        25.2
# 10    01/04/2022  12:50:27            21.7          23.2        25.9
# 11    01/04/2022  12:50:47            21.8          23.6        26.5
# ...          ...       ...             ...           ...         ...
# 1283  01/04/2022  19:54:47            34.8          71.8        74.9
# 1284  01/04/2022  19:55:07            34.8          71.8        74.9
# 1285  01/04/2022  19:55:27            34.9          71.9        74.9
# 1286  01/04/2022  19:55:47            34.8          71.9        74.9
# 1287  01/04/2022  19:56:07            34.9          71.9        74.9
#
#       intermed_past  intermed_resist  parede_ceramica  sup_pastilha  \
# 7              21.2             22.0             20.2          21.5
# ...

# %%
data[dia_01]["aleta_ceramica"].mean()
plt.plot(data[dia_01]['TIME'], data[dia_01]['aleta_ceramica'], label='aleta_ceramica',color = "red")
plt.axhline(y=data[dia_01]["aleta_ceramica"].mean(), color='black', linestyle='--', label='Média')

plt.show()
